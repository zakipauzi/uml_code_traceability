# %%
# %pip install -r requirements.txt

# %%
# %pip install torch-2.3.1+cu118-cp311-cp311-win_amd64.whl

# %%
# %pip install torchaudio==2.3.1
# %pip install torchvision==0.18.1

# %%
import pandas as pd

sampled_repo_graphics_df = pd.read_csv("sampled_repo_graphics_df.csv")
sampled_repo_graphics_df = sampled_repo_graphics_df.head(10)
sampled_repo_graphics_df = sampled_repo_graphics_df.sort_values(by=['Graphic_Files_Length'])
sampled_repo_graphics_df
# Out:
#                        Project              Last_Activity  Contributors  \
# 1                  baidu/broc/  2024-10-25 16:02:35+00:00           4.0
# 8        athiasjerome/XORCISM/  2024-06-19 18:25:44+00:00           1.0
# 5           andrenho/perminal/  2024-11-09 16:47:23+00:00           1.0
# 3          Splamy/TS3AudioBot/  2024-11-14 13:01:16+00:00          12.0
# 0             sprossiter/JSIT/  2024-08-26 23:12:56+00:00           1.0
# 4               benmfaul/XRTB/  2024-05-17 07:27:22+00:00           1.0
# 7  aplgithub/haikudepotserver/  2024-11-09 13:06:22+00:00          17.0
# 2             telldus/telldus/  2024-09-09 12:44:16+00:00          10.0
# 6       borman/phoneme-qtopia/  2024-11-03 10:35:55+00:00           2.0
# 9         tazzledazzle/UW-CSS/  2024-03-02 12:42:33+00:00           1.0
#
#    Stargazers                                      Graphic_Files  \
# 1       100.0  ['doc/dependent_relationship.jpg', 'doc/flowch...
# 8        23.0  ['Documentation/XORCISM_Architecture_Overview_...
# 5         0.0  ['.old/cpp/frontend/latin1.png', '.old/rust/da...
# 3       698.0  ['TS3AudioBot/Media/SleepingKitty.png', 'TS3Au...
# 0         2.0  ['src/main/resources/docs/diagrams/alAddDepend...
# 4       121.0  ['src/Test.uml', 'src/com/xrtb/bidder/Campaign...
# 7        18.0  ['docs/images/img-architectureoverview.png', '...
# 2        64.0  ['telldus-gui/3rdparty/qtsingleapplication/doc...
# 6        11.0  ['cldc/src/tools/memprof_client/doc/vm_memprof...
# 9         4.0  ['343/lab4/lab4classUML.jpg', '490/assignment1...
#
#    Graphic_Files_Length
# 1                     3
# 8                     3
# 5                     4
# 3                     5
# 0                     6
# 4                    54
# 7                    65
# 2                   106
# 6                   490
# 9                  1257

# %%
print(sampled_repo_graphics_df['Graphic_Files_Length'].sum())
# Out:
# 1993

# %%
import torch 
torch.cuda.is_available()
# Out:
# True

# %%
from transformers import AutoModel, AutoTokenizer

filepath_model = "C:/Users/biadge/MiniCPM-o-2_6"  # path to the model
model = AutoModel.from_pretrained(filepath_model, 
                                  trust_remote_code=True, 
                                  use_safetensors=True,
                                  attn_implementation='sdpa', 
                                  torch_dtype=torch.bfloat16, 
                                  init_vision=True,
                                  init_audio=True,
                                  init_tts=True)

model = model.eval().cuda()

tokenizer = AutoTokenizer.from_pretrained(filepath_model, trust_remote_code=True)
model.init_tts()
# Out:
# c:\Users\biadge\uml_code_traceability\.venv\Lib\site-packages\transformers\models\auto\image_processing_auto.py:513: FutureWarning: The image_processor_class argument is deprecated and will be removed in v4.42. Please use `slow_image_processor_class`, or `fast_image_processor_class` instead
#   warnings.warn(
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]

# %% [markdown]
# ## Test against sliced df

# %%
# convert list in Graphic Files to strings in separate rows

import ast
from PIL import Image

sampled_repo_graphics_df['Graphic_Files'] = sampled_repo_graphics_df['Graphic_Files'].apply(lambda x: ast.literal_eval(x))
sampled_repo_graphics_df = sampled_repo_graphics_df.explode('Graphic_Files')
sampled_repo_graphics_df = sampled_repo_graphics_df.drop(columns=['Graphic_Files_Length'])
sampled_repo_graphics_df = sampled_repo_graphics_df.reset_index(drop=True)
sampled_repo_graphics_df
# Out:
#                     Project              Last_Activity  Contributors  \
# 0               baidu/broc/  2024-10-25 16:02:35+00:00           4.0
# 1               baidu/broc/  2024-10-25 16:02:35+00:00           4.0
# 2               baidu/broc/  2024-10-25 16:02:35+00:00           4.0
# 3     athiasjerome/XORCISM/  2024-06-19 18:25:44+00:00           1.0
# 4     athiasjerome/XORCISM/  2024-06-19 18:25:44+00:00           1.0
# ...                     ...                        ...           ...
# 1988   tazzledazzle/UW-CSS/  2024-03-02 12:42:33+00:00           1.0
# 1989   tazzledazzle/UW-CSS/  2024-03-02 12:42:33+00:00           1.0
# 1990   tazzledazzle/UW-CSS/  2024-03-02 12:42:33+00:00           1.0
# 1991   tazzledazzle/UW-CSS/  2024-03-02 12:42:33+00:00           1.0
# 1992   tazzledazzle/UW-CSS/  2024-03-02 12:42:33+00:00           1.0
#
#       Stargazers                                      Graphic_Files
# 0          100.0                     doc/dependent_relationship.jpg
# 1          100.0                                  doc/flowchart.jpg
# 2          100.0                           doc/sequence_diagram.jpg
# 3           23.0  Documentation/XORCISM_Architecture_Overview_TA...
# 4           23.0  Documentation/XORCISM_Technical_Architecture_O...
# ...          ...                                                ...
# 1988         4.0  490/assignment4/AudioFeatureMining/weka/gui/we...
# 1989         4.0  490/assignment4/AudioFeatureMining/weka/gui/we...
# 1990         4.0  490/assignment4/AudioFeatureMining/weka/gui/we...
# 1991         4.0  490/assignment4/AudioFeatureMining/weka/gui/we...
# 1992         4.0  490/assignment4/AudioFeatureMining/weka/gui/we...
#
# [1993 rows x 5 columns]

# %%
import requests
import os

def run_detect_uml(model, tokenizer, project, file):

    image_url = f"https://raw.githubusercontent.com/{project[:-1]}/master/{file}".format(project=project, file=file)

    # from the image url, download the image to a temporary file which will be deleted later

    os.makedirs(f'images/{project}', exist_ok=True)
    with open(f'images/{project}/{os.path.basename(file)}', 'wb') as f:
        f.write(requests.get(image_url).content)

    try:
        image = Image.open(f'images/{project}/{os.path.basename(file)}').convert('RGB')
    except:
        return "Error"

    question = "Is this image a UML class diagram? Only answer 'True' if yes or 'False' if no."
    msgs=[{'role': 'user', 
           'content': [image,question]}]
    res = model.chat(
        msgs=msgs,
        tokenizer=tokenizer
    )

    return res

# %%
from tqdm.notebook import tqdm
tqdm.pandas()

sampled_repo_graphics_uml_df = sampled_repo_graphics_df.copy()
sampled_repo_graphics_uml_df['Is_UML'] = sampled_repo_graphics_uml_df.progress_apply(lambda x: run_detect_uml(model, 
                                                                                                              tokenizer, 
                                                                                                              x['Project'], 
                                                                                                              x['Graphic_Files']), 
                                                                                                              axis=1)
# Out:
#   0%|          | 0/1993 [00:00<?, ?it/s]
# The `seen_tokens` attribute is deprecated and will be removed in v4.41. Use the `cache_position` model input instead.
# c:\Users\biadge\uml_code_traceability\.venv\Lib\site-packages\transformers\models\qwen2\modeling_qwen2.py:580: UserWarning: 1Torch was not compiled with flash attention. (Triggered internally at ..\aten\src\ATen\native\transformers\cuda\sdp_utils.cpp:455.)
#   attn_output = torch.nn.functional.scaled_dot_product_attention(
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 5
#       2 tqdm.pandas()
#       4 sampled_repo_graphics_uml_df = sampled_repo_graphics_df.copy()
# ----> 5 sampled_repo_graphics_uml_df['Is_UML'] = sampled_repo_graphics_uml_df.progress_apply(lambda x: run_detect_uml(model,
#       6                                                                                                               tokenizer,
#       7                                                                                                               x['Project'],
#       8                                                                                                               x['Graphic_Files']),
#       9                                                                                                               axis=1)
#
# File c:\Users\biadge\uml_code_traceability\.venv\Lib\site-packages\tqdm\std.py:917, in tqdm.pandas.<locals>.inner_generator.<locals>.inner(df, func, *args, **kwargs)
#     914 # Apply the provided function (in **kwargs)
#     915 # on the df using our wrapper (which provides bar updating)
#     916 try:
# --> 917     return getattr(df, df_function)(wrapper, **kwargs)
#     918 finally:
#     919     t.close()
#
# File c:\Users\biadge\uml_code_traceability\.venv\Lib\site-packages\pandas\core\frame.py:10374, in DataFrame.apply(self, func, axis, raw, result_type, args, by_row, engine, engine_kwargs, **kwargs)
#   10360 from pandas.core.apply import frame_apply
#   10362 op = frame_apply(
#   10363     self,
#   10364     func=func,
#    (...)
#   10372     kwargs=kwargs,
#   10373 )
# > 10374 return op.apply().__finalize__(self, method="apply")
#
# File c:\Users\biadge\uml_code_traceability\.venv\Lib\site-packages\pandas\core\apply.py:916, in FrameApply.apply(self)
#     913 elif self.raw:
#     914     return self.apply_raw(engine=self.engine, engine_kwargs=self.engine_kwargs)
# --> 916 return self.apply_standard()
#
# File c:\Users\biadge\uml_code_traceability\.venv\Lib\site-packages\pandas\core\apply.py:1063, in FrameApply.apply_standard(self)
#    1061 def apply_standard(self):
#    1062     if self.engine == "python":
# -> 1063         results, res_index = self.apply_series_generator()
#    1064     else:
#    1065         results, res_index = self.apply_series_numba()
#
# File c:\Users\biadge\uml_code_traceability\.venv\Lib\site-packages\pandas\core\apply.py:1081, in FrameApply.apply_series_generator(self)
#    1078 with option_context("mode.chained_assignment", None):
#    1079     for i, v in enumerate(series_gen):
#    1080         # ignore SettingWithCopy here in case the user mutates
# -> 1081         results[i] = self.func(v, *self.args, **self.kwargs)
#    1082         if isinstance(results[i], ABCSeries):
#    1083             # If we have a view on v, we need to make a copy because
#    1084             #  series_generator will swap out the underlying data
#    1085             results[i] = results[i].copy(deep=False)
#
# File c:\Users\biadge\uml_code_traceability\.venv\Lib\site-packages\tqdm\std.py:912, in tqdm.pandas.<locals>.inner_generator.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     906 def wrapper(*args, **kwargs):
#     907     # update tbar correctly
#     908     # it seems `pandas apply` calls `func` twice
#     909     # on the first column/row to decide whether it can
#     910     # take a fast or slow code path; so stop when t.total==t.n
#     911     t.update(n=1 if not t.total or t.n < t.total else 0)
# --> 912     return func(*args, **kwargs)
#
# Cell In[10], line 5, in <lambda>(x)
#       2 tqdm.pandas()
#       4 sampled_repo_graphics_uml_df = sampled_repo_graphics_df.copy()
# ----> 5 sampled_repo_graphics_uml_df['Is_UML'] = sampled_repo_graphics_uml_df.progress_apply(lambda x: run_detect_uml(model,
#       6                                                                                                               tokenizer,
#       7                                                                                                               x['Project'],
#       8                                                                                                               x['Graphic_Files']),
#       9                                                                                                               axis=1)
#
# Cell In[9], line 22, in run_detect_uml(model, tokenizer, project, file)
#      19 question = "Is this image a UML class diagram? Only answer 'True' if yes or 'False' if no."
#      20 msgs=[{'role': 'user',
#      21        'content': [image,question]}]
# ---> 22 res = model.chat(
#      23     msgs=msgs,
#      24     tokenizer=tokenizer
#      25 )
#      27 return res
#
# File ~\.cache\huggingface\modules\transformers_modules\MiniCPM-o-2_6\modeling_minicpmo.py:994, in MiniCPMO.chat(self, image, msgs, tokenizer, processor, vision_hidden_states, max_new_tokens, min_new_tokens, sampling, max_inp_length, stream, chunk_input, omni_input, max_slice_nums, use_image_id, use_tts_template, generate_audio, return_spk_embed, return_dict, output_audio_path, **kwargs)
#     992 inputs.pop("image_sizes")
#     993 with torch.inference_mode():
# --> 994     res, outputs = self.generate(
#     995         **inputs,
#     996         tokenizer=tokenizer,
#     997         max_new_tokens=max_new_tokens,
#     998         vision_hidden_states=vision_hidden_states,
#     999         stream=stream,
#    1000         **generation_config,
#    1001     )
#    1003 if stream:
#    1005     def stream_gen():
#
# File ~\.cache\huggingface\modules\transformers_modules\MiniCPM-o-2_6\modeling_minicpmo.py:813, in MiniCPMO.generate(self, input_ids, pixel_values, tgt_sizes, audio_features, audio_feature_lens, image_bound, audio_bounds, spk_bounds, attention_mask, tokenizer, vision_hidden_states, stream, **kwargs)
#     811         outputs = {}
#     812     else:
# --> 813         outputs = self._decode(model_inputs["inputs_embeds"], tokenizer, attention_mask, **kwargs)
#     815         result = self._decode_text(outputs.sequences, tokenizer)
#     817 return result, outputs
#
# File ~\.cache\huggingface\modules\transformers_modules\MiniCPM-o-2_6\modeling_minicpmo.py:639, in MiniCPMO._decode(self, inputs_embeds, tokenizer, attention_mask, **kwargs)
#     637 def _decode(self, inputs_embeds, tokenizer, attention_mask, **kwargs):
#     638     terminators = [tokenizer.convert_tokens_to_ids(i) for i in self.terminators]
# --> 639     outputs = self.llm.generate(
#     640         inputs_embeds=inputs_embeds,
#     641         pad_token_id=0,
#     642         eos_token_id=terminators,
#     643         attention_mask=attention_mask,
#     644         output_hidden_states=True,
#     645         return_dict_in_generate=True,
#     646         **kwargs,
#     647     )
#     648     return outputs
#
# File c:\Users\biadge\uml_code_traceability\.venv\Lib\site-packages\torch\utils\_contextlib.py:115, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     112 @functools.wraps(func)
#     113 def decorate_context(*args, **kwargs):
#     114     with ctx_factory():
# --> 115         return func(*args, **kwargs)
#
# File c:\Users\biadge\uml_code_traceability\.venv\Lib\site-packages\transformers\generation\utils.py:2024, in GenerationMixin.generate(self, inputs, generation_config, logits_processor, stopping_criteria, prefix_allowed_tokens_fn, synced_gpus, assistant_model, streamer, negative_prompt_ids, negative_prompt_attention_mask, **kwargs)
#    2016     input_ids, model_kwargs = self._expand_inputs_for_generation(
#    2017         input_ids=input_ids,
#    2018         expand_size=generation_config.num_return_sequences,
#    2019         is_encoder_decoder=self.config.is_encoder_decoder,
#    2020         **model_kwargs,
#    2021     )
#    2023     # 13. run sample (it degenerates to greedy search when `generation_config.do_sample=False`)
# -> 2024     result = self._sample(
#    2025         input_ids,
#    2026         logits_processor=prepared_logits_processor,
#    2027         logits_warper=prepared_logits_warper,
#    2028         stopping_criteria=prepared_stopping_criteria,
#    2029         generation_config=generation_config,
#    2030         synced_gpus=synced_gpus,
#    2031         streamer=streamer,
#    2032         **model_kwargs,
#    2033     )
#    2035 elif generation_mode in (GenerationMode.BEAM_SAMPLE, GenerationMode.BEAM_SEARCH):
#    2036     # 11. prepare logits warper
#    2037     prepared_logits_warper = (
#    2038         self._get_logits_warper(generation_config, device=input_ids.device)
#    2039         if generation_config.do_sample
#    2040         else None
#    2041     )
#
# File c:\Users\biadge\uml_code_traceability\.venv\Lib\site-packages\transformers\generation\utils.py:3020, in GenerationMixin._sample(self, input_ids, logits_processor, stopping_criteria, generation_config, synced_gpus, streamer, logits_warper, **model_kwargs)
#    3018     probs = nn.functional.softmax(next_token_scores, dim=-1)
#    3019     # TODO (joao): this OP throws "skipping cudagraphs due to ['incompatible ops']", find solution
# -> 3020     next_tokens = torch.multinomial(probs, num_samples=1).squeeze(1)
#    3021 else:
#    3022     next_tokens = torch.argmax(next_token_scores, dim=-1)
#
# KeyboardInterrupt:

# %%
sampled_repo_graphics_uml_df
# Out:
#                  Project              Last_Activity  Contributors  Stargazers  \
# 0            baidu/broc/  2024-10-25 16:02:35+00:00           4.0       100.0
# 1            baidu/broc/  2024-10-25 16:02:35+00:00           4.0       100.0
# 2            baidu/broc/  2024-10-25 16:02:35+00:00           4.0       100.0
# 3    Splamy/TS3AudioBot/  2024-11-14 13:01:16+00:00          12.0       698.0
# 4    Splamy/TS3AudioBot/  2024-11-14 13:01:16+00:00          12.0       698.0
# ..                   ...                        ...           ...         ...
# 169     telldus/telldus/  2024-09-09 12:44:16+00:00          10.0        64.0
# 170     telldus/telldus/  2024-09-09 12:44:16+00:00          10.0        64.0
# 171     telldus/telldus/  2024-09-09 12:44:16+00:00          10.0        64.0
# 172     telldus/telldus/  2024-09-09 12:44:16+00:00          10.0        64.0
# 173     telldus/telldus/  2024-09-09 12:44:16+00:00          10.0        64.0
#
#                                          Graphic_Files Is_UML
# 0                       doc/dependent_relationship.jpg  False
# 1                                    doc/flowchart.jpg  False
# 2                             doc/sequence_diagram.jpg  False
# 3                  TS3AudioBot/Media/SleepingKitty.png  False
# 4                  TS3AudioBot/Media/SleepingKitty.svg  Error
# ..                                                 ...    ...
# 169  telldus-gui/TelldusGui/images/vendors/sartano.png  False
# 170      telldus-gui/TelldusGui/images/vendors/upm.png  False
# 171  telldus-gui/TelldusGui/images/vendors/waveman.png  False
# 172      telldus-gui/TelldusGui/images/vendors/x10.png  False
# 173                                   xpl/data/uml.xmi  Error
#
# [174 rows x 6 columns]

# %%
sampled_repo_graphics_uml_df.to_csv("sampled_repo_graphics_uml_df.csv", index=False)
